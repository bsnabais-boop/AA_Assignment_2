# %%
import pandas as pd

# %%
data = pd.read_csv('train_data.csv')
data
# Out:
#      Unnamed: 0   Age  Gender  Stage  GeneticRisk  TreatmentType  \
# 0             0  65.0       0      2          1.0              0
# 1             1  68.0       1      2          0.0              1
# 2             2  68.0       1      3          1.0              1
# 3             3  81.0       1      4          1.0              1
# 4             4  59.0       1      2          1.0              0
# ..          ...   ...     ...    ...          ...            ...
# 395         395  66.0       0      3          0.0              1
# 396         396  72.0       1      2          NaN              0
# 397         397  69.0       0      2          0.0              0
# 398         398  63.0       0      4          0.0              1
# 399         399  67.0       0      2          0.0              1
#
#      ComorbidityIndex  TreatmentResponse  SurvivalTime  Censored
# 0                 0.0                0.0           4.2         0
# ...

# %% [markdown]
# ## Task 1
